# %%
import pandas as pd
dataset = pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\GivenData\dataset.csv")
dataset.head()
# Out:
#           0         1
# 0  0.374540  0.950714
# 1  0.731994  0.598658
# 2  0.156019  0.155995
# 3  0.058084  0.866176
# 4  0.601115  0.708073

# %%
generated_dataset= pd.DataFrame({
    'feat_01': [],
    'feat_11': [],
    'feat_02': [],
    'feat_12': [],
    'feat_03': [],
    'feat_13': [],
    'feat_04': [],
    'feat_14': [],
    'feat_05': [],
    'feat_15': [],
    'feat_06': [],
    'feat_16': [],
    'feat_07': [],
    'feat_17': [],
    'feat_08': [],
    'feat_18': [],
    'feat_09': [],
    'feat_19': [],
    'feat_10': [],
    'feat_20': [],
})
start = 0
end = 100

# %%
generated_dataset= pd.DataFrame({
    'feat_01': [],
    'feat_11': [],
    'feat_02': [],
    'feat_12': [],
    'feat_03': [],
    'feat_13': [],
    'feat_04': [],
    'feat_14': [],
    'feat_05': [],
    'feat_15': [],
})
start = 0
end = 200
def average(num1, num2, col):
    sum=0
    if col==0:
        for i in range(num1,num2):
            sum=sum+dataset.iloc[i][0]        
        return (sum / 200)
    else:
        for i in range(num1,num2):
            sum=sum+dataset.iloc[i][1]        
        return (sum / 200)

for i in range(0,1000):
    row_values = {}
    row_values['feat_01'] = average((i*1000)+start,(i*1000)+end,0)
    row_values['feat_11'] = average((i*1000)+start,(i*1000)+end,1)
    row_values['feat_02'] = average((i*1000)+start+200,(i*1000)+end+200,0)
    row_values['feat_12'] = average((i*1000)+start+200,(i*1000)+end+200,1)
    row_values['feat_03'] = average((i*1000)+start+400,(i*1000)+end+400,0)
    row_values['feat_13'] = average((i*1000)+start+400,(i*1000)+end+400,1) 
    row_values['feat_04'] = average((i*1000)+start+600,(i*1000)+end+600,0)
    row_values['feat_14'] = average((i*1000)+start+600,(i*1000)+end+600,1) 
    row_values['feat_05'] = average((i*1000)+start+800,(i*1000)+end+800,0)
    row_values['feat_15'] = average((i*1000)+start+800,(i*1000)+end+800,1) 
    generated_dataset = generated_dataset.append(row_values, ignore_index=True)
    
generated_dataset
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11388/3574795934.py in <module>
#      26 for i in range(0,1000):
#      27     row_values = {}
# ---> 28     row_values['feat_01'] = average((i*1000)+start,(i*1000)+end,0)
#      29     row_values['feat_11'] = average((i*1000)+start,(i*1000)+end,1)
#      30     row_values['feat_02'] = average((i*1000)+start+200,(i*1000)+end+200,0)
#
# ~\AppData\Local\Temp/ipykernel_11388/3574795934.py in average(num1, num2, col)
#      17     if col==0:
#      18         for i in range(num1,num2):
# ---> 19             sum=sum+dataset.iloc[i][0]
#      20         return (sum / 200)
#      21     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     927
#     928     def __getitem__(self, key):
# --> 929         key = com.apply_if_callable(key, self)
#     930
# ...

# %%
def average(num1, num2, col):
    sum=0
    if col==0:
        for i in range(num1,num2):
            sum=sum+dataset.iloc[i][0]        
        return (sum / 100)
    else:
        for i in range(num1,num2):
            sum=sum+dataset.iloc[i][1]        
        return (sum / 100)

for i in range(0,1000):
    row_values = {}
    row_values['feat_01'] = average((i*1000)+start,(i*1000)+end,0)
    row_values['feat_11'] = average((i*1000)+start,(i*1000)+end,1)
    row_values['feat_02'] = average((i*1000)+start+100,(i*1000)+end+100,0)
    row_values['feat_12'] = average((i*1000)+start+100,(i*1000)+end+100,1)
    row_values['feat_03'] = average((i*1000)+start+200,(i*1000)+end+200,0)
    row_values['feat_13'] = average((i*1000)+start+200,(i*1000)+end+200,1) 
    row_values['feat_04'] = average((i*1000)+start+300,(i*1000)+end+300,0)
    row_values['feat_14'] = average((i*1000)+start+300,(i*1000)+end+300,1) 
    row_values['feat_05'] = average((i*1000)+start+400,(i*1000)+end+400,0)
    row_values['feat_15'] = average((i*1000)+start+400,(i*1000)+end+400,1)
    row_values['feat_06'] = average((i*1000)+start+500,(i*1000)+end+500,0)
    row_values['feat_16'] = average((i*1000)+start+500,(i*1000)+end+500,1)
    row_values['feat_07'] = average((i*1000)+start+600,(i*1000)+end+600,0)
    row_values['feat_17'] = average((i*1000)+start+600,(i*1000)+end+600,1)
    row_values['feat_08'] = average((i*1000)+start+700,(i*1000)+end+700,0)
    row_values['feat_18'] = average((i*1000)+start+700,(i*1000)+end+700,1) 
    row_values['feat_09'] = average((i*1000)+start+800,(i*1000)+end+800,0)
    row_values['feat_19'] = average((i*1000)+start+800,(i*1000)+end+800,1) 
    row_values['feat_10'] = average((i*1000)+start+900,(i*1000)+end+900,0)
    row_values['feat_20'] = average((i*1000)+start+900,(i*1000)+end+900,1) 
    generated_dataset = generated_dataset.append(row_values, ignore_index=True)
    
generated_dataset
# Out:
#       feat_01   feat_11   feat_02   feat_12   feat_03   feat_13   feat_04  \
# 0    0.481044  0.486969  0.515593  0.493157  0.491411  0.549935  0.401676
# 1    0.478212  0.548385  0.521679  0.446725  0.477501  0.539180  0.501873
# 2    0.526323  0.459707  0.450813  0.507267  0.493952  0.497920  0.471637
# 3    0.442803  0.502893  0.503478  0.515182  0.513544  0.481230  0.535383
# 4    0.518410  0.462852  0.489649  0.488234  0.500948  0.496938  0.446881
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.540703  0.490289  0.518789  0.492476  0.522340  0.529057  0.531298
# 996  0.506968  0.511160  0.478138  0.440772  0.479246  0.423303  0.474514
# 997  0.512571  0.506665  0.509589  0.517250  0.513387  0.453938  0.543093
# 998  0.461656  0.552086  0.525060  0.510565  0.497849  0.492505  0.490341
# 999  0.475340  0.437935  0.470153  0.519232  0.507031  0.511787  0.438727
#
#       feat_14   feat_05   feat_15   feat_06   feat_16   feat_07   feat_17  \
# ...

# %%
generated_dataset.to_csv("generateds_10f_sine.csv", index=False)

# %%
generated_dataset.to_csv("generateds_sine.csv", index=False)

# %%
import pandas as pd
import numpy as np
generated_dataset=pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\GeneratedData\\generateds_sine.csv")
acc = pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\GivenData\population_accuracies.csv")
acc.head()
generated_dataset.head()
# Out:
#     feat_01   feat_11   feat_02   feat_12   feat_03   feat_13   feat_04  \
# 0  0.498318  0.490063  0.446543  0.552901  0.503430  0.503679  0.505715
# 1  0.499945  0.497555  0.489687  0.501211  0.511438  0.499303  0.502233
# 2  0.488568  0.483487  0.482794  0.515958  0.508867  0.481210  0.496787
# 3  0.473141  0.509037  0.524464  0.471599  0.527711  0.466738  0.459753
# 4  0.504029  0.475543  0.473914  0.481306  0.493057  0.518223  0.498906
#
#     feat_14   feat_05   feat_15
# 0  0.487652  0.490680  0.507388
# 1  0.496702  0.495341  0.470488
# 2  0.502803  0.491173  0.511201
# 3  0.494285  0.471517  0.480152
# 4  0.488500  0.488003  0.494978

# %%
model = pd.read_json("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\GivenData\\population_steps.json")
pop_model = pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\GeneratedData\\MinmaxHoeff_Models.csv")
pd_df = {"Class": []}
temp = None
accuracy_list=[np.nan] * 1000
for i in range(0, 1000):
    accuracy=0
    for j in range(0, 10):
        curr = model[j][i]['Scaler']+str(model[j][i]['Classifier'])
        #print('curr',curr)
        pop = str(pop_model.loc[2][0])
        #print('pop',pop)
        if pop == curr:
            print('curr',curr)
            if(temp==i):
                accuracy=(accuracy+acc.loc[i][j])/2
            else:
                accuracy=acc.loc[i][j]
            #print('accuracy', accuracy)
            #print("i:", {i}, "j:", {j})
            temp=i
    accuracy_list[i]=accuracy
accuracy_list
# Out:
# curr MinMaxScaler['HoeffdingTreeClassifier', {'max_depth': 10, 'grace_period': 10, '_max_size': 5}]
# curr MinMaxScaler['HoeffdingTreeClassifier', {'max_depth': 10, 'grace_period': 10, '_max_size': 5}]
# curr MinMaxScaler['HoeffdingTreeClassifier', {'max_depth': 10, 'grace_period': 10, '_max_size': 5}]
# curr MinMaxScaler['HoeffdingTreeClassifier', {'max_depth': 10, 'grace_period': 10, '_max_size': 5}]
# curr MinMaxScaler['HoeffdingTreeClassifier', {'max_depth': 10, 'grace_period': 10, '_max_size': 5}]
# curr MinMaxScaler['HoeffdingTreeClassifier', {'max_depth': 10, 'grace_period': 10, '_max_size': 5}]
# curr MinMaxScaler['HoeffdingTreeClassifier', {'max_depth': 10, 'grace_period': 10, '_max_size': 5}]
# curr MinMaxScaler['HoeffdingTreeClassifier', {'max_depth': 10, 'grace_period': 10, '_max_size': 5}]
# curr MinMaxScaler['HoeffdingTreeClassifier', {'max_depth': 10, 'grace_period': 10, '_max_size': 5}]
# ...

# %%
generated_dataset["Accuracy"] = accuracy_list
generated_dataset
# Out:
#       feat_01   feat_11   feat_02   feat_12   feat_03   feat_13   feat_04  \
# 0    0.498318  0.490063  0.446543  0.552901  0.503430  0.503679  0.505715
# 1    0.499945  0.497555  0.489687  0.501211  0.511438  0.499303  0.502233
# 2    0.488568  0.483487  0.482794  0.515958  0.508867  0.481210  0.496787
# 3    0.473141  0.509037  0.524464  0.471599  0.527711  0.466738  0.459753
# 4    0.504029  0.475543  0.473914  0.481306  0.493057  0.518223  0.498906
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.529746  0.491383  0.526819  0.496995  0.491058  0.499470  0.545679
# 996  0.492553  0.475966  0.476880  0.472155  0.484770  0.479413  0.528994
# 997  0.511080  0.511957  0.528240  0.491594  0.500823  0.480323  0.492267
# 998  0.493358  0.531325  0.494095  0.521971  0.511401  0.483213  0.506154
# 999  0.472746  0.478583  0.472879  0.483175  0.513421  0.483747  0.465437
#
#       feat_14   feat_05   feat_15  Accuracy
# ...

# %%
# save the generated dataset as a CSV file
generated_dataset.to_csv("generateds_minmaxhoeff_5feat_10_10_5_sine.csv", index=False)
