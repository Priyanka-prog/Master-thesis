# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka-prog/Master-thesis/blob/main/Scripts/SyntheticDatasetp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
n=50
mu,sigma=0,0.1

# %%
header = ['x','y','f']

# %%
with open('syntheticdataset.csv','w',newline='') as file:
  writer=csv.writer(file)
  writer.writerow(header)
  for i in range(1,n):
    for j in range(1,n):
      noise = np. random. normal(mu,sigma,1)
      target=4*i*i-3*i*j+ noise
      [writer.writerow([i,j,target[0]])]

# %%
import pandas as pd

df = pd.read_csv('syntheticdataset.csv', parse_dates=False)
df.y.plot(color='g',lw=1.3)
df.f.plot(color='r',lw=1.3)

# %%
pip install chart-studio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 64 kB 2.7 MB/s
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=6a5cc2e918d3a3ef33c99d55c72e3b0b778f4b1f1c0401d2e3192ae59397f6d7
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# ...

# %%
import matplotlib.pyplot as plt
from chart_studio import plotly
from mpl_toolkits.mplot3d import axes3d
from IPython.display import HTML
from matplotlib import animation

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
with open('syntheticdataset.csv', 'r') as f:
    obj = csv.reader(f)
    X, Y, Z = [], [], []
    for i,row in enumerate(obj):
        if i>0:
             xstring = row[0]
             ystring = row[1]
             zstring= row[2]
             X.append(float(xstring))
             Y.append(float(ystring))
             Z.append(float(zstring))
ax.scatter3D(X,Y,Z);

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x,y)')
plt.show()

def animate(frame):
  ax.view_init(30, frame/4)
  plt.pause(.001)
  return fig

anim = animation.FuncAnimation(fig, animate, frames=200, interval=50)
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(X,Z);
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(Y,Z);
plt.show()

# %%
plt.plot(X, Z, color = 'g', linestyle = 'dashed',
		marker = 'o',label = "X versus f(x,y)")

plt.xticks(rotation = 25)
plt.xlabel('X')
plt.ylabel('f(x,y)')
plt.title('X versus f(x,y)', fontsize = 20)
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(Y, Z, color = 'g', linestyle = 'dashed',
		marker = 'o',label = "Y versus f(x,y)")

plt.xticks(rotation = 25)
plt.xlabel('Y')
plt.ylabel('f(x,y)')
plt.title('Y versus f(x,y)', fontsize = 20)
plt.grid()
plt.legend()
plt.show()
