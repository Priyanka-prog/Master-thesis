# %%
import pandas as pd

# %%
prediction_LRR = pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\Results\\minmax_hoeff_dt_predict\prediction.csv", low_memory=False)

# %%
prediction_LRR.head()
# Out:
#    real      pred
# 0   1.0  0.983366
# 1   1.0  0.999030
# 2   1.0  0.999775
# 3   1.0  0.999030
# 4   1.0  0.998566

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrameXG
prediction_LRR = pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\\acc_test_predict_norm_LRR\prediction.csv", low_memory=False)

# Extract the "real" and "pred" values as separate lists
real = prediction_LRR["real"].tolist()
pred = prediction_LRR["pred"].tolist()

# Create a list of row numbers for the x-axis
x = list(range(1, len(real) + 1))

# Create a scatter plot
plt.scatter(x, real, label="Real", s=10)
plt.scatter(x, pred, label="Pred", s=10)

# Add a legend and axis labels
plt.legend(bbox_to_anchor =(1, 0.5))
plt.title("LRRidge")
plt.xlabel("Instance")
plt.ylabel("Accuracy_value")

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrameXG
prediction_XG = pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\\acc_test_predict_norm_XG\prediction.csv", low_memory=False)

# Extract the "real" and "pred" values as separate lists
real = prediction_XG["real"].tolist()
pred = prediction_XG["pred"].tolist()

# Create a list of row numbers for the x-axis
x = list(range(1, len(real) + 1))

# Create a scatter plot
plt.scatter(x, real, label="Real", s=10)
plt.scatter(x, pred, label="Pred", s=10)

# Add a legend and axis labels
plt.legend(bbox_to_anchor =(1, 0.5))
plt.title("XGBoost")
plt.xlabel("Instance")
plt.ylabel("Accuracy_value")

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
prediction_SVR = pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\\acc_test_predict_norm_SVR\prediction.csv", low_memory=False)

# Extract the "real" and "pred" values as separate lists
real = prediction_SVR["real"].tolist()
pred = prediction_SVR["pred"].tolist()

# Create a list of row numbers for the x-axis
x = list(range(1, len(real) + 1))

# Create a scatter plot
plt.scatter(x, real, label="Real", s=10)
plt.scatter(x, pred, label="Pred", s=10)

# Add a legend and axis labels
plt.legend(bbox_to_anchor =(1, 0.5))
plt.title("SVR")
plt.xlabel("Instance")
plt.ylabel("Accuracy_value")

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
prediction_DT = pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\\acc_test_predict_norm_DT\prediction.csv", low_memory=False)

# Extract the "real" and "pred" values as separate lists
real = prediction_DT["real"].tolist()
pred = prediction_DT["pred"].tolist()

# Create a list of row numbers for the x-axis
x = list(range(1, len(real) + 1))

# Create a scatter plot
plt.scatter(x, real, label="Real", s=10)
plt.scatter(x, pred, label="Pred", s=10)

# Add a legend and axis labels
plt.legend(bbox_to_anchor =(1, 0.5))
plt.title("Decision Tree")
plt.xlabel("Instance")
plt.ylabel("Accuracy_value")

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
prediction_RF = pd.read_csv("F:\Laurea Magistrale\Master Thesis\Dataset\Sine\\acc_test_predict_norm_RF\prediction.csv", low_memory=False)

# Extract the "real" and "pred" values as separate lists
real = prediction_RF["real"].tolist()
pred = prediction_RF["pred"].tolist()

# Create a list of row numbers for the x-axis
x = list(range(1, len(real) + 1))

# Create a scatter plot
plt.scatter(x, real, label="Real", s=10)
plt.scatter(x, pred, label="Pred", s=10)

# Add a legend and axis labels
plt.legend(bbox_to_anchor =(1, 0.5))
plt.title("Random Forest")
plt.xlabel("Instance")
plt.ylabel("Accuracy_value")

# Show the plot
plt.show()
